# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
image=cv2.imread("im.jpg")
image=image.astype(dtype='uint8')
blur=((5,5),1)
erode_=(2,2)
dilate_=(5, 5)
X = cv2.dilate(image, None, iterations=1)
X= cv2.erode(image, None, iterations=1)

X=X.astype(dtype='uint8')

plt.imshow(X)
cv2.imwrite('result.jpg',X)
# Out:
# True

# %%
print(X.shape)
# Out:
# (396, 720, 3)
